# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Lenovo\Desktop\machine learning company projects\project-2(seoul bike trip duration)\For_modeling.csv')
df.head(20)
# Out:
#     Unnamed: 0  Duration  Distance      PLong       PLatd      DLong  \
# 0            0         3        50  37.544666  126.888359  37.544666
# 1            1        24      7670  37.506199  127.003944  37.551250
# 2            2         8      1390  37.544590  127.057083  37.537014
# 3            3         8      1820  37.571102  127.023560  37.561447
# 4            4         4       850  37.573242  127.015907  37.565849
# 5            5         8      1800  37.571102  127.023560  37.561447
# 6            6        25      4770  37.593288  127.036667  37.582500
# 7            7         4       630  37.552914  126.836571  37.557968
# 8            8         3       950  37.459953  127.024742  37.455799
# 9            9        25      3900  37.527122  127.028717  37.539654
# 10          10        27      4750  37.570721  126.898979  37.578072
# 11          11        23      4820  37.570721  126.898979  37.578072
# 12          12        16      2930  37.599491  126.916862  37.620949
# ...

# %%
df.shape
# Out:
# (9601139, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9601139 entries, 0 to 9601138
# Data columns (total 26 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   Duration    int64
#  2   Distance    int64
#  3   PLong       float64
#  4   PLatd       float64
#  5   DLong       float64
#  6   DLatd       float64
#  7   Haversine   float64
#  8   Pmonth      int64
#  9   Pday        int64
#  10  Phour       int64
#  11  Pmin        int64
#  12  PDweek      int64
#  13  Dmonth      int64
#  14  Dday        int64
#  15  Dhour       int64
#  16  Dmin        int64
#  17  DDweek      int64
#  18  Temp        float64
#  19  Precip      float64
#  20  Wind        float64
#  21  Humid       float64
#  22  Solar       float64
#  23  Snow        float64
#  24  GroundTemp  float64
#  25  Dust        float64
# dtypes: float64(13), int64(13)
# memory usage: 1.9 GB

# %%
##The prediction is carried out with the combination of Seoul Bike data and weather data.
##Four performance metrics
##(i)Root mean squared error,(ii) Coefficient of Variance, (iii)Mean Absolute Error and (iv)Median Absolute Error 
##can be used to determine the efficiency of the models
##Tasks – EDA, Pre-processing, Modelling, Feature Engineering, Evaluation, explainability, Deployment
###Target variable is 'Duration'.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Duration      0
# Distance      0
# PLong         0
# PLatd         0
# DLong         0
# DLatd         0
# Haversine     0
# Pmonth        0
# Pday          0
# Phour         0
# Pmin          0
# PDweek        0
# Dmonth        0
# Dday          0
# Dhour         0
# Dmin          0
# DDweek        0
# Temp          0
# Precip        0
# Wind          0
# Humid         0
# Solar         0
# Snow          0
# GroundTemp    0
# Dust          0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0      Duration      Distance         PLong         PLatd  \
# count  9.601139e+06  9.601139e+06  9.601139e+06  9.601139e+06  9.601139e+06
# mean   4.923152e+06  2.580294e+01  3.713519e+03  3.754761e+01  1.269908e+02
# std    2.841734e+06  2.504333e+01  3.956611e+03  4.441376e-02  8.257065e-02
# min    0.000000e+00  1.000000e+00  1.000000e+00  3.743727e+01  1.267986e+02
# 25%    2.466320e+06  8.000000e+00  1.230000e+03  3.751424e+01  1.269200e+02
# 50%    4.921318e+06  1.600000e+01  2.280000e+03  3.754693e+01  1.269943e+02
# 75%    7.389176e+06  3.600000e+01  4.620000e+03  3.757324e+01  1.270618e+02
# max    9.830310e+06  1.190000e+02  3.329000e+04  3.768972e+01  1.271803e+02
#
#               DLong         DLatd     Haversine        Pmonth          Pday  \
# count  9.601139e+06  9.601139e+06  9.601139e+06  9.601139e+06  9.601139e+06
# mean   3.754770e+01  1.269907e+02  1.870315e+00  7.578754e+00  1.576714e+01
# ...

# %%
df['Unnamed: 0']
# Out:
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
#             ...
# 9601134    9830306
# 9601135    9830307
# 9601136    9830308
# 9601137    9830309
# 9601138    9830310
# Name: Unnamed: 0, Length: 9601139, dtype: int64

# %%
df['Duration']
# Out:
# 0            3
# 1           24
# 2            8
# 3            8
# 4            4
#           ...
# 9601134     67
# 9601135     58
# 9601136    118
# 9601137     90
# 9601138    116
# Name: Duration, Length: 9601139, dtype: int64

# %%
df['Distance']
# Out:
# 0             50
# 1           7670
# 2           1390
# 3           1820
# 4            850
#            ...
# 9601134     6930
# 9601135     8320
# 9601136     2730
# 9601137    17170
# 9601138     1410
# Name: Distance, Length: 9601139, dtype: int64

# %%
n=len(df)
print(n)
# Out:
# 9601139

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9601139 entries, 0 to 9601138
# Data columns (total 26 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   Duration    int64
#  2   Distance    int64
#  3   PLong       float64
#  4   PLatd       float64
#  5   DLong       float64
#  6   DLatd       float64
#  7   Haversine   float64
#  8   Pmonth      int64
#  9   Pday        int64
#  10  Phour       int64
#  11  Pmin        int64
#  12  PDweek      int64
#  13  Dmonth      int64
#  14  Dday        int64
#  15  Dhour       int64
#  16  Dmin        int64
#  17  DDweek      int64
#  18  Temp        float64
#  19  Precip      float64
#  20  Wind        float64
#  21  Humid       float64
#  22  Solar       float64
#  23  Snow        float64
#  24  GroundTemp  float64
#  25  Dust        float64
# dtypes: float64(13), int64(13)
# memory usage: 1.9 GB

# %%
df.drop('PLatd', axis=1, inplace =True)

# %%
df.drop('DLatd', axis=1, inplace =True)

# %%
df.drop('Pday', axis=1, inplace =True)

# %%
df.drop('Pmin', axis=1, inplace =True)

# %%
df.drop('Dday', axis=1, inplace =True)

# %%
df.drop('Dmin',axis=1,inplace =True)

# %%
df.drop('Precip', axis=1, inplace =True)

# %%
df.drop('Snow', axis=1, inplace =True)

# %%
df.drop('Dust', axis=1, inplace =True)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9601139 entries, 0 to 9601138
# Data columns (total 16 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Duration    int64
#  1   Distance    int64
#  2   PLong       float64
#  3   DLong       float64
#  4   Haversine   float64
#  5   Pmonth      int64
#  6   Phour       int64
#  7   PDweek      int64
#  8   Dmonth      int64
#  9   Dhour       int64
#  10  DDweek      int64
#  11  Temp        float64
#  12  Wind        float64
#  13  Humid       float64
#  14  Solar       float64
#  15  GroundTemp  float64
# dtypes: float64(8), int64(8)
# memory usage: 1.1 GB

# %%
df.head(10)
# Out:
#    Duration  Distance      PLong      DLong  Haversine  Pmonth  Phour  PDweek  \
# 0         3        50  37.544666  37.544666   0.000000       1      0       0
# 1        24      7670  37.506199  37.551250   5.713529       1      0       0
# 2         8      1390  37.544590  37.537014   0.913702       1      0       0
# 3         8      1820  37.571102  37.561447   1.468027       1      0       0
# 4         4       850  37.573242  37.565849   0.823227       1      0       0
# 5         8      1800  37.571102  37.561447   1.468027       1      0       0
# 6        25      4770  37.593288  37.582500   3.567644       1      0       0
# 7         4       630  37.552914  37.557968   0.581982       1      0       0
# 8         3       950  37.459953  37.455799   0.877524       1      0       0
# 9        25      3900  37.527122  37.539654   2.524430       1      0       0
#
#    Dmonth  Dhour  DDweek  Temp  Wind  Humid  Solar  GroundTemp
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X = df.iloc[:,1:14]  #independent columns
Y = df.iloc[:,-16]    #target column i.e Duration

# %%
X
# Out:
#          Duration  Distance      PLong       PLatd      DLong       DLatd  \
# 0               3        50  37.544666  126.888359  37.544666  126.888359
# 1              24      7670  37.506199  127.003944  37.551250  127.035103
# 2               8      1390  37.544590  127.057083  37.537014  127.061096
# 3               8      1820  37.571102  127.023560  37.561447  127.034920
# 4               4       850  37.573242  127.015907  37.565849  127.016403
# ...           ...       ...        ...         ...        ...         ...
# 9601134        67      6930  37.562607  127.051308  37.562607  127.051308
# 9601135        58      8320  37.511982  127.085052  37.476028  127.105942
# 9601136       118      2730  37.506199  127.003944  37.514870  127.015282
# 9601137        90     17170  37.489750  126.927467  37.565903  126.901184
# 9601138       116      1410  37.585655  127.075050  37.585655  127.075050
#
#          Haversine  Pmonth  Pday  Phour  Pmin  PDweek  Dmonth
# ...

# %%
Y
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 9601134    23
# 9601135    23
# 9601136    22
# 9601137    23
# 9601138    23
# Name: Phour, Length: 9601139, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.4, random_state=20)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()
##A correlation of -1.0 indicates a perfect negative correlation,
##and a correlation of 1.0 indicates a perfect positive correlation. If the correlation coefficient is greater than zero, it is a positive relationship.
##Conversely, if the value is less than zero, it is a negative relationship. 
##A value of zero indicates that there is no relationship between the two variables.

# %%
##EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.pairplot(df[['Wind','Temp']], size=3)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
##EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.pairplot(df[['Pmonth','Dmonth']], size=3)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
##EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.pairplot(df[['DDweek','PDweek']], size=3)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
##EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.pairplot(df[['Phour','Dhour']], size=3)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
##EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.pairplot(df[['Distance','Temp']], size=3)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
##EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.pairplot(df[['Distance','Dhour']], size=3)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
##EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.pairplot(df[['PLong','DLong']], size=3)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.4, random_state=20)

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))
# Out:
# 4

# %%
corr_features
# Out:
# {'DDweek', 'DLong', 'Dhour', 'Dmonth'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#          Distance      PLong  Haversine  Pmonth  Phour  PDweek  Temp  Wind  \
# 1227580      1220  37.572227   0.930422       4      9       2  11.7   0.8
# 1845630      1060  37.554859   0.881990       5     18       3  22.6   1.1
# 9483128       680  37.493126   0.613528      12     11       5   8.3   1.1
# 5851153      5820  37.512169   4.082787       9     21       6  22.2   1.2
# 3644381      4690  37.568344   3.952097       7     22       5  22.6   1.7
# ...           ...        ...        ...     ...    ...     ...   ...   ...
# 598984        900  37.479431   0.832184       3      9       4   3.3   1.4
# 2040371      2440  37.494007   3.444811       5     10       3  19.9   2.7
# 5795762      9060  37.547070   5.596436       9     20       5  22.8   2.0
# 1910896      2380  37.539551   0.000000       5     10       6  17.0   1.4
# 5501776      5510  37.566383   4.644136       9      0       6  23.5   1.5
#
#          Humid
# 1227580   32.0
# 1845630   97.0
# 9483128   41.0
# ...

# %%
X_train.drop(corr_features,axis=1)
# Out:
#          Distance      PLong  Haversine  Pmonth  Phour  PDweek  Temp  Wind  \
# 2174613      2240  37.582592   1.789392       5      0       0  17.3   0.7
# 4654069      5640  37.462688   0.753103       8      9       1  29.3   1.1
# 5772266      7460  37.574200   5.065904       9     13       5  26.1   3.0
# 2796310      4860  37.507233   4.057315       6     13       3  22.8   1.2
# 9456095      2450  37.493618   1.665208      12      0       4   1.2   1.0
# ...           ...        ...        ...     ...    ...     ...   ...   ...
# 1697172      1920  37.548405   1.368153       5     22       3  12.3   2.3
# 3890076      1980  37.488453   1.001939       7      5       6  24.5   0.7
# 5528799      1980  37.524334   1.272989       9     18       6  27.9   1.7
# 2976218      1170  37.505180   0.344401       6     21       0  23.8   2.0
# 9420131      7730  37.576508   0.364337      12     12       2   6.4   1.8
#
#          Humid
# 2174613   55.0
# 4654069   66.0
# 5772266   32.0
# ...

# %%
##linear regression
##gradient boosting mechanism
##knn
##random forest

# %%
##random forest regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
X,Y = make_regression(n_features=4, n_informative=2,random_state=0, shuffle=False)
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(X,Y)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
from sklearn.metrics import accuracy_score
y_pred_lr = rfr.predict(X_test)
print('Accuracy of random forest regression classifier on test set: {:.2f}'.format(rfr.score(X_test, Y_test)))
# Out:
# Accuracy of random forest regression classifier on test set: 0.96

# %%
##KNN REGRESSOR
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

x_train_scaled = scaler.fit_transform(X_train)
x_train = pd.DataFrame(x_train_scaled)

x_test_scaled = scaler.fit_transform(X_test)
x_test = pd.DataFrame(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score
y_pred_lr = rfr.predict(X_test)
print('Accuracy of KNN regressor on test set: {:.2f}'.format(rfr.score(X_test, Y_test)))
# Out:
# Accuracy of KNN regressor on test set: 0.96

# %%
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 37.07952247587201
# RMSE value for k=  2 is: 36.421400557808134
# RMSE value for k=  3 is: 31.103444329341826
# RMSE value for k=  4 is: 29.78779223202987
# RMSE value for k=  5 is: 30.651088434089857
# RMSE value for k=  6 is: 29.73080791023407
# RMSE value for k=  7 is: 27.97863553004166
# RMSE value for k=  8 is: 28.65949846945053
# RMSE value for k=  9 is: 29.284162167546082
# RMSE value for k=  10 is: 29.599866211228367
# RMSE value for k=  11 is: 29.81658811778148
# RMSE value for k=  12 is: 30.28951359570031
# RMSE value for k=  13 is: 30.32068325118071
# RMSE value for k=  14 is: 30.70422269210405
# RMSE value for k=  15 is: 31.204340314732406
# RMSE value for k=  16 is: 30.99157740834824
# RMSE value for k=  17 is: 31.548966984318827
# RMSE value for k=  18 is: 32.13090808492914
# RMSE value for k=  19 is: 31.95292237133125
# RMSE value for k=  20 is: 31.64618747180183

# %%
curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot()
# Out:
# <AxesSubplot:>

# %%
##LINEAR REGRESSION
from sklearn import linear_model

regr = linear_model.LinearRegression()

regr.fit(X_train,Y_train)

# predicting on cv

pred_cv = regr.predict(X_test)

# %%
#Training
regr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# The coefficients
print('Coefficients', regr.coef_)
print('Intercept',regr.intercept_)
# Out:
# Coefficients [ 4.15953315e+01  2.31254953e+01  4.29855249e-14 -2.73361698e-15
#   3.71559853e-14 -5.89684747e-15 -8.33142816e-15 -1.42005837e-14
#  -3.09824793e-14  2.48300291e-14 -1.69870330e-14  2.89152400e-15
#  -1.13872095e-14]
# Intercept -6.217248937900877e-15

# %%
#Testing
y_pred = regr.predict(X_test)

# %%
y_pred
# Out:
# array([  9.92627412,  51.10491256,  -2.42537855, -22.78587937,
#        -22.15598527,  38.05088976,   9.37378011, -26.74575596,
#         -7.49090447, -43.61897229, 106.67264324, -12.94974677,
#        -53.86383182,  34.4786494 ,  55.66446992,  18.44715515,
#        -15.46932553, -63.76797795,   0.43072663,  -3.84925429,
#         14.83340941,  20.1109464 , -36.82268978,   9.58462251,
#        -24.59339565, -43.96076293, -11.66027948, -20.06679682,
#          3.1851891 ,  50.61111596,  74.00566229,  76.41669065,
#        -18.73435753, -52.23076111,  -6.29202337, -28.24993809,
#        -30.02619846,  47.38411017,   0.69727085,  31.53655569])

# %%
#Evaluation
from sklearn.metrics import mean_squared_error, r2_score
print(r2_score(Y_test, y_pred)) #Coefficient of Determination
print(mean_squared_error(Y_test, y_pred)) #MSE
# Out:
# 1.0
# 5.851406887504757e-27

# %%
from sklearn.preprocessing import Normalizer

cement_n = Normalizer().fit_transform(df)
cement_n = pd.DataFrame(cement_n)
print(cement_n)
# Out:
#                0         1         2         3         4         5         6   \
# 0        0.000000  0.015040  0.250659  0.188218  0.636115  0.188218  0.636115
# 1        0.000130  0.003128  0.999672  0.004888  0.016553  0.004894  0.016557
# 2        0.001425  0.005700  0.990434  0.026752  0.090534  0.026747  0.090536
# 3        0.001639  0.004371  0.994385  0.020528  0.069401  0.020522  0.069407
# 4        0.004589  0.004589  0.975079  0.043102  0.145707  0.043094  0.145707
# ...           ...       ...       ...       ...       ...       ...       ...
# 9601134  1.000000  0.000007  0.000705  0.000004  0.000013  0.000004  0.000013
# 9601135  1.000000  0.000006  0.000846  0.000004  0.000013  0.000004  0.000013
# 9601136  1.000000  0.000012  0.000278  0.000004  0.000013  0.000004  0.000013
# 9601137  0.999998  0.000009  0.001747  0.000004  0.000013  0.000004  0.000013
# 9601138  1.000000  0.000012  0.000143  0.000004  0.000013  0.000004  0.000013
#
# ...

# %%
#Multi-Collinearity
import numpy as np
X = np.array(X)
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif = [variance_inflation_factor(X, i) for i in range(X.shape[1])]
print(vif)
X = pd.DataFrame(X)
# Out:
# [1.037235700534572, 1.0662751125524454, 1.0773941271394356, 1.008288213819014]

# %%
#Feature Selection 
from sklearn.feature_selection import RFE

logreg = linear_model.LinearRegression()
rfe = RFE(logreg, 6)
rfe = rfe.fit(X,Y)

print(rfe.support_)
print(rfe.ranking_)
# Out:
# [ True  True  True  True]
# [1 1 1 1]

# %%
d = rfe.support_

g = X.columns

a = g[d]

X_f = X[a]

# %%
X_f.head()
# Out:
#           0         1         2         3
# 0  1.764052  0.400157  0.978738  2.240893
# 1  1.867558 -0.977278  0.950088 -0.151357
# 2 -0.103219  0.410599  0.144044  1.454274
# 3  0.761038  0.121675  0.443863  0.333674
# 4  1.494079 -0.205158  0.313068 -0.854096

# %%
import statsmodels.api as sm

# %%
results_1 = sm.OLS(Y,X).fit()
results_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          1.638e+31
# Date:                Sun, 22 Aug 2021   Prob (F-statistic):                        0.00
# Time:                        16:26:53   Log-Likelihood:                          2927.3
# No. Observations:                 100   AIC:                                     -5847.
# Df Residuals:                      96   BIC:                                     -5836.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
##ridge and lasso
##ridge
from sklearn.linear_model import Ridge

## training the model

ridgeReg = Ridge(alpha=0.05, normalize=True)

ridgeReg.fit(X_train,Y_train)

pred = ridgeReg.predict(X_test)

##calculating mse

mse = np.mean((pred_cv - Y_test)**2)
mse
# Out:
# 5.851406887504757e-27

# %%
## calculating score 
ridgeReg.score(X_test,Y_test)
# Out:
# 0.9955530296781263

# %%
##lasso
from sklearn.linear_model import Lasso

lassoReg = Lasso(alpha=0.3, normalize=True)

lassoReg.fit(X_train,Y_train)

pred = lassoReg.predict(X_test)

# calculating mse

mse = np.mean((pred_cv - Y_test)**2)
mse
# Out:
# 5.851406887504757e-27

# %%
lassoReg.score(X_test,Y_test)
# Out:
# 0.9948631859267516

# %%
##elasticnet regression
from sklearn.linear_model import ElasticNet

ENreg = ElasticNet(alpha=1, l1_ratio=0.5, normalize=False)

ENreg.fit(X_train,Y_train)

pred_cv = ENreg.predict(X_test)

#calculating mse

mse = np.mean((pred_cv - Y_test)**2)

mse
# Out:
# 231.8446454177534

# %%
ENreg.score(X_test,Y_test)
# Out:
# 0.840527267692533

# %%
#Evaluation
from sklearn.metrics import mean_squared_error, r2_score
print(r2_score(Y_test, y_pred)) #Coefficient of Determination
print(mean_squared_error(Y_test, y_pred)) #MSE
# Out:
# 1.0
# 5.851406887504757e-27

# %%
##gradient boosting mechanism 
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
params = {'n_estimators': 500,
          'max_depth': 4,
          'min_samples_split': 5,
          'learning_rate': 0.01,
          'loss': 'ls'}

# %%
reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=4, min_samples_split=5,
#                           n_estimators=500)

# %%
reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, Y_train)

mse = mean_squared_error(Y_test, reg.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# The mean squared error (MSE) on test set: 208.6954

# %%
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)
for i, y_pred in enumerate(reg.staged_predict(X_test)):
    test_score[i] = reg.loss_(Y_test, y_pred)

fig = plt.figure(figsize=(6, 6))
plt.subplot(1, 1, 1)
plt.title('Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, reg.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')
fig.tight_layout()
plt.show()
